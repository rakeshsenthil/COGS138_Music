# %%
import pandas as pd
import numpy as np
import os
import mne
import mne
import scipy
import librosa
import matplotlib.pyplot as plt
import librosa.display

# %%
from scipy.io import wavfile

# %%
a = mne.io.read_raw_edf('./sub-01/eeg/sub-01_task-run2_eeg.edf')
# Out:
# Extracting EDF parameters from /Users/rakesh/Downloads/COGS138/COGS138_Music/sub-01/eeg/sub-01_task-run2_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# /var/folders/1_/1fj443x17f1f_17vd86ds4p40000gn/T/ipykernel_31539/3777767741.py:1: RuntimeWarning: Invalid date encountered (2014-00-00 00:00:00).
#   a = mne.io.read_raw_edf('./sub-01/eeg/sub-01_task-run2_eeg.edf')

# %%
a
# Out:
# <RawEDF | sub-01_task-run2_eeg.edf, 37 x 841000 (841.0 s), ~40 kB, data not loaded>

# %%
b = mne.io.read_raw_edf('./sub-16/eeg/sub-16_task-run1_eeg.edf')

b
# Out:
# Extracting EDF parameters from /Users/rakesh/Downloads/COGS138/COGS138_Music/sub-16/eeg/sub-16_task-run1_eeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# /var/folders/1_/1fj443x17f1f_17vd86ds4p40000gn/T/ipykernel_31579/163144710.py:1: RuntimeWarning: Invalid date encountered (2014-00-00 00:00:00).
#   b = mne.io.read_raw_edf('./sub-16/eeg/sub-16_task-run1_eeg.edf')
# <RawEDF | sub-16_task-run1_eeg.edf, 37 x 927000 (927.0 s), ~40 kB, data not loaded>

# %%
b.plot(duration=5, n_channels=30)
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
b.plot_psd(fmax=50)
# Out:
# Effective window size : 2.048 (s)
# /var/folders/1_/1fj443x17f1f_17vd86ds4p40000gn/T/ipykernel_31539/3948141362.py:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   b.plot_psd(fmax=50)
# <MNELineFigure size 720x252 with 1 Axes>
# <MNELineFigure size 720x252 with 1 Axes>

# %%
a = pd.read_json('./sub-16/eeg/sub-16_task-run1_events.json')
a
# Out:
#                                                              1  \
# LongName                                                  LVLA
# Description  Low valence, low arousal targetted affect, sta...
#
#                                                              2  \
# LongName                                                  NVLA
# Description  Neutral valence, low arousal targetted affect,...
#
#                                                              3  \
# LongName                                                  HVLA
# Description  High valence, low arousal targetted affect, st...
#
#                                                              4  \
# LongName                                                  LVNA
# Description  Low valence, neutral arousal targetted affect,...
#
#                                                              5  \
# LongName                                                  NVNA
# Description  Neutral valence, neutral arousal targetted aff...
#
#                                                              6  \
# LongName                                                  HVNA
# Description  High valence, neutral arousal targetted affect...
#
#                                                              7  \
# LongName                                                  LVHA
# Description  Low valence, high arousal targetted affect, st...
#
#                                                              8  \
# LongName                                                  NVHA
# Description  Neutral valence, high arousal targetted affect...
#
#                                                              9  \
# LongName                                                  HVHA
# Description  High valence, high arousal targetted affect, s...
#
#                                                        101-209
# LongName                                           musicPlayed
# Description  The piece of music played to the participant. ...

# %%
wav_files = ['hvha1.wav', 'hvha10.wav', 'hvha11.wav', 'hvha12.wav', 'hvha2.wav',         'hvha3.wav', 'hvha4.wav', 'hvha5.wav', 'hvha6.wav', 'hvha7.wav',        'hvha8.wav', 'hvha9.wav', 'hvla1.wav', 'hvla10.wav', 'hvla11.wav',       'hvla12.wav', 'hvla2.wav', 'hvla3.wav', 'hvla4.wav', 'hvla5.wav',        'hvla6.wav', 'hvla7.wav', 'hvla8.wav', 'hvla9.wav',         'hvna1.wav', 'hvna10.wav', 'hvna11.wav', 'hvna12.wav', 'hvna2.wav',         'hvna3.wav', 'hvna4.wav', 'hvna5.wav', 'hvna6.wav', 'hvna7.wav' ,         'hvna8.wav', 'hvna9.wav', 'lvha1.wav', 'lvha10.wav', 'lvha11.wav',         'lvha12.wav', 'lvha2.wav', 'lvha3.wav' ,'lvha4.wav', 'lvha5.wav',         'lvha6.wav', 'lvha7.wav', 'lvha8.wav', 'lvha9.wav', 'lvla1.wav' ,         'lvla10.wav', 'lvla11.wav', 'lvla12.wav', 'lvla2.wav', 'lvla3.wav',         'lvla4.wav', 'lvla5.wav',  'lvla6.wav', 'lvla7.wav', 'lvla8.wav' ,         'lvla9.wav', 'lvna1.wav', 'lvna10.wav', 'lvna11.wav' , 'lvna12.wav',         'lvna2.wav', 'lvna3.wav', 'lvna4.wav', 'lvna5.wav', 'lvna6.wav',         'lvna7.wav', 'lvna8.wav', 'lvna9.wav', 'nvha1.wav', 'nvha10.wav',         'nvha11.wav', 'nvha12.wav', 'nvha2.wav', 'nvha3.wav', 'nvha4.wav',         'nvha5.wav', 'nvha6.wav', 'nvha7.wav', 'nvha8.wav', 'nvha9.wav',         'nvla1.wav', 'nvla10.wav', 'nvla11.wav', 'nvla12.wav', 'nvla2.wav',         'nvla3.wav', 'nvla4.wav', 'nvla5.wav', 'nvla6.wav', 'nvla7.wav',         'nvla8.wav', 'nvla9.wav', 'nvna1.wav', 'nvna10.wav', 'nvna11.wav',         'nvna12.wav', 'nvna2.wav', 'nvna3.wav', 'nvna4.wav', 'nvna5.wav',         'nvna6.wav', 'nvna7.wav', 'nvna8.wav', 'nvna9.wav']

# %%
wav_files[77-1]
# Out:
# 'nvha2.wav'

# %%
rate, nvha3 = wavfile.read('./stimuli/nvha3.wav')
nvha_array = np.array(nvha3.T,dtype=float)

# %%
nvha_array
# Out:
# array([[-1.,  2., -3., ...,  1., -2.,  2.],
#        [ 0.,  1., -2., ...,  0., -2.,  1.]])

# %%
tempo_test = librosa.beat.tempo(nvha_array)
tempo_test
# Out:
# /Users/rakesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Pass y=[[-1.  2. -3. ...  1. -2.  2.]
#  [ 0.  1. -2. ...  0. -2.  1.]] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   """Entry point for launching an IPython kernel.
# array([[89.10290948],
#        [89.10290948]])

# %%
rate
# Out:
# 44100

# %%
flatness_nvha3 = librosa.feature.spectral_flatness(nvha_array, n_fft = len(nvha_array))
# temp = flatness_nvha3[0,0]
# plt.hist(temp)
flatness_nvha3.shape
# Out:
# /Users/rakesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Pass y=[[-1.  2. -3. ...  1. -2.  2.]
#  [ 0.  1. -2. ...  0. -2.  1.]] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   """Entry point for launching an IPython kernel.
# (2, 1, 1707)

# %%
init_df = pd.read_csv('./sub-16/eeg/sub-16_task-run1_events.tsv', sep = '\t')
init_df
# Out:
#       onset  duration  trial_type
# 0     9.643        21           6
# 1     9.643        21         177
# 2    60.806        21           1
# 3    60.806        21         155
# 4   117.798        21           2
# 5   117.798        21         186
# 6   167.199        21           9
# 7   167.199        21         134
# 8   221.160        21           5
# 9   221.160        21         205
# 10  277.655        21           7
# 11  277.655        21         146
# 12  330.626        21           9
# 13  330.626        21         104
# 14  384.956        21           7
# 15  384.956        21         142
# 16  440.033        21           7
# 17  440.033        21         143
# 18  490.001        21           9
# 19  490.001        21         129
# 20  541.674        21           7
# 21  541.674        21         138
# 22  589.518        21           4
# 23  589.518        21         167
# 24  643.108        21           1
# 25  643.108        21         150
# 26  690.557        21           1
# 27  690.557        21         158
# 28  735.874        21           9
# 29  735.874        21         110
# 30  785.483        21           9
# 31  785.483        21         131
# 32  832.135        21           9
# 33  832.135        21         130
# 34  881.612        21           6
# 35  881.612        21         182

# %%
start_times = np.unique(init_df['onset'])
start_times
# Out:
# array([  9.643,  60.806, 117.798, 167.199, 221.16 , 277.655, 330.626,
#        384.956, 440.033, 490.001, 541.674, 589.518, 643.108, 690.557,
#        735.874, 785.483, 832.135, 881.612])

# %%
def ind(e, L):
    return L.index(e) if e in L else len(L)

# %%
# channel_sample = b.get_data().shape
# eeg_sample = b.get_data()
# all_eeg = np.zeros([len(start_times), channel_sample[0], 21*1000])
# for i,j in enumerate(start_times):
# #     all_eeg[i] = eeg_sample[:, ind(start_times[i] * 1000)]
#     all_eeg[i] = eeg_sample[eeg_sample.index(start_times[i])]

# epoch data - create an epoch for each song presentation

# settings
FS = 1000 # sampling frequency
DURATION = 21 # song duration (sec)

# get EEG data from MNE object
eeg = b.get_data()

# initialize matrix for epoched data
n_samples = FS * DURATION # calculate number of EEG samples per epoch
n_channels = eeg.shape[0] # count number of channels
epochs = np.zeros([len(start_times), n_channels, n_samples])

# loop through song start times
for i_st, st in enumerate(start_times):
    # get index of start and end time for epoch 
    start = int(st * 1000)
#     end = start + n_samples - 1
    end = start + n_samples
    
    # aggregate data
    epochs[i_st] = eeg[:, start:end]

# %%
len(epochs)
# Out:
# 18

# %%
import pylab
S = librosa.feature.melspectrogram(nvha_array, sr=1000)
S
# Out:
# /Users/rakesh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Pass y=[[-1.  2. -3. ...  1. -2.  2.]
#  [ 0.  1. -2. ...  0. -2.  1.]] as keyword args. From version 0.10 passing these as positional arguments will result in an error
# array([[[1.95433457e+00, 8.70697556e+00, 6.59232535e+00, ...,
#          2.77328831e+09, 1.78670566e+09, 2.91949296e+08],
#         [1.05601022e+00, 5.62904275e+00, 6.60540483e+00, ...,
#          8.18551396e+08, 3.94248517e+08, 7.51845730e+07],
#         [2.25081131e+00, 7.56442969e+00, 6.23360867e+00, ...,
#          1.66217200e+08, 4.82854921e+07, 1.16210564e+07],
#         ...,
#         [1.03828608e+04, 2.01460955e+04, 4.35783147e+04, ...,
#          2.31282516e+04, 1.19654762e+04, 2.77519659e+04],
#         [8.24805206e+03, 1.37903790e+04, 3.30672086e+04, ...,
#          2.80976830e+04, 1.54805148e+04, 1.15158455e+04],
#         [2.89030397e+04, 5.82040130e+04, 5.42734885e+04, ...,
#          3.61999978e+04, 1.75939302e+04, 1.47127718e+04]],
#
#        [[5.32704398e+00, 9.57648643e+00, 6.31705927e+00, ...,
#          1.42266427e+09, 9.76587814e+08, 1.83542836e+08],
#         [5.56342373e+00, 1.10615209e+01, 8.24538119e+00, ...,
#          8.28349361e+08, 3.53071768e+08, 7.07895076e+07],
#         [6.57886577e+00, 1.30006138e+01, 6.19836452e+00, ...,
#          2.59741308e+08, 8.56054421e+07, 1.84331657e+07],
#         ...,
#         [1.04235382e+04, 3.53304831e+04, 5.47627301e+04, ...,
#          3.00545055e+04, 4.68802766e+04, 5.20231420e+04],
#         [1.21478401e+04, 3.69036898e+04, 4.72004680e+04, ...,
#          2.38806856e+04, 3.69082296e+04, 3.31832708e+04],
#         [2.63803369e+04, 5.31186163e+04, 3.78972335e+04, ...,
#          2.71606778e+04, 3.00493070e+04, 1.78249674e+04]]])

# %%
test_mne = mne.time_frequency.psd_welch(b)
len(test_mne[0])
# Out:
# Effective window size : 0.256 (s)
# 37

# %%
wav_files = ['hvha1.wav', 'hvha10.wav', 'hvha11.wav', 'hvha12.wav', 'hvha2.wav','hvha3.wav', 'hvha4.wav', 'hvha5.wav', 'hvha6.wav', 'hvha7.wav',        'hvha8.wav', 'hvha9.wav', 'hvla1.wav', 'hvla10.wav', 'hvla11.wav',       'hvla12.wav', 'hvla2.wav', 'hvla3.wav', 'hvla4.wav', 'hvla5.wav',        'hvla6.wav', 'hvla7.wav', 'hvla8.wav', 'hvla9.wav',         'hvna1.wav', 'hvna10.wav', 'hvna11.wav', 'hvna12.wav', 'hvna2.wav',         'hvna3.wav', 'hvna4.wav', 'hvna5.wav', 'hvna6.wav', 'hvna7.wav' ,         'hvna8.wav', 'hvna9.wav', 'lvha1.wav', 'lvha10.wav', 'lvha11.wav',         'lvha12.wav', 'lvha2.wav', 'lvha3.wav' ,'lvha4.wav', 'lvha5.wav',         'lvha6.wav', 'lvha7.wav', 'lvha8.wav', 'lvha9.wav', 'lvla1.wav' ,         'lvla10.wav', 'lvla11.wav', 'lvla12.wav', 'lvla2.wav', 'lvla3.wav',         'lvla4.wav', 'lvla5.wav',  'lvla6.wav', 'lvla7.wav', 'lvla8.wav' ,         'lvla9.wav', 'lvna1.wav', 'lvna10.wav', 'lvna11.wav' , 'lvna12.wav',         'lvna2.wav', 'lvna3.wav', 'lvna4.wav', 'lvna5.wav', 'lvna6.wav',         'lvna7.wav', 'lvna8.wav', 'lvna9.wav', 'nvha1.wav', 'nvha10.wav',         'nvha11.wav', 'nvha12.wav', 'nvha2.wav', 'nvha3.wav', 'nvha4.wav',         'nvha5.wav', 'nvha6.wav', 'nvha7.wav', 'nvha8.wav', 'nvha9.wav',         'nvla1.wav', 'nvla10.wav', 'nvla11.wav', 'nvla12.wav', 'nvla2.wav',         'nvla3.wav', 'nvla4.wav', 'nvla5.wav', 'nvla6.wav', 'nvla7.wav',         'nvla8.wav', 'nvla9.wav', 'nvna1.wav', 'nvna10.wav', 'nvna11.wav',         'nvna12.wav', 'nvna2.wav', 'nvna3.wav', 'nvna4.wav', 'nvna5.wav',         'nvna6.wav', 'nvna7.wav', 'nvna8.wav', 'nvna9.wav']
df = pd.DataFrame({'onset': init_df['onset'].iloc[::2].values, 'song_type':init_df['trial_type'].iloc[::2].values, 'song_value':init_df['trial_type'].iloc[1::2].values})
df['song_value'] = df['song_value'] - 100
list_of_songs = []
for i in df.song_value:
    file_name = wav_files[i-1]
    list_of_songs.append(file_name)

# %%
list_of
# Out:
#       onset  song_type  song_value
# 0     9.643          6          77
# 1    60.806          1          55
# 2   117.798          2          86
# 3   167.199          9          34
# 4   221.160          5         105
# 5   277.655          7          46
# 6   330.626          9           4
# 7   384.956          7          42
# 8   440.033          7          43
# 9   490.001          9          29
# 10  541.674          7          38
# 11  589.518          4          67
# 12  643.108          1          50
# 13  690.557          1          58
# 14  735.874          9          10
# 15  785.483          9          31
# 16  832.135          9          30
# 17  881.612          6          82
